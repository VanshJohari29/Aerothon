# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
exf=pd.ExcelFile("data.xlsx")
df1=exf.parse("fabrication")
df1.describe()
# Out:
#        item item id raw material Quantity     in date             out date
# count    28      28           28       28          28                   28
# unique    7      27            8       11           6                    8
# top     tub    T124     plastics  10 sqft  27/02/2020  2020-05-03 00:00:00
# freq      5       2            7        5           8                    4

# %%
df.head()
# Out:
#            item item id                        raw material  Quantity  \
# 0           tub    T101                         sheet steel   10 sqft
# 1          pump    T102                            plastics     10 kg
# 2      spin tub    T103                     stainless steel   5 kg/m3
# 3      wash tub    T104  (enameling iron) Porcelain coating  24 gauge
# 4  balance ring    T105                            plastics     3 kg
#
#       in date             out date
# 0  14/02/2020           21/02/2020
# 1  16/02/2020           20/02/2020
# 2  27/02/2020  2020-05-03 00:00:00
# 3  27/02/2020  2020-03-02 00:00:00
# 4  16/03/2020           21/03/2020

# %%
df2=exf.parse("assembly")
df2.describe()
df2.head()
# Out:
#                    process         Process ID           Machine ID  \
# 0    Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# 1       Electrical Testing  SAWM3042_FA_WM134  MAII1017ECME3020080
# 2               Complaince  SAWM3042_FA_WM135  MAII1017ECME3020081
# 3  Certification Standards  SAWM3042_FA_WM136  MAII1017ECME3020082
# 4               pivot dome  SAWM3042_FA_WM137  MAII1017ECME3020083
#
#    2020-09-03 00:00:00  2020-11-30 00:00:00 Start Date    END DATE  \
# 0                  NaN                  NaN  2020-10-19 2020-12-11
# 1                  NaN                  NaN  2020-11-26 2020-12-05
# 2                  NaN                  NaN  2020-09-10 2021-02-02
# 3                  NaN                  NaN  2020-08-03 2021-01-06
# 4                  NaN                  NaN  2020-10-18 2021-01-05
#
#    2020-12-02 00:00:00  2021-02-02 00:00:00
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# ...

# %%
print(df2.isnull().sum())
# Out:
# process                 0
# Process ID              0
# Machine ID              0
# 2020-09-03 00:00:00    36
# 2020-11-30 00:00:00    36
# Start Date              0
# END DATE                0
# 2020-12-02 00:00:00    36
# 2021-02-02 00:00:00    36
# dtype: int64

# %%
df2 = df2.dropna(axis=1)
df2.head()
# Out:
#                    process         Process ID           Machine ID  \
# 0    Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# 1       Electrical Testing  SAWM3042_FA_WM134  MAII1017ECME3020080
# 2               Complaince  SAWM3042_FA_WM135  MAII1017ECME3020081
# 3  Certification Standards  SAWM3042_FA_WM136  MAII1017ECME3020082
# 4               pivot dome  SAWM3042_FA_WM137  MAII1017ECME3020083
#
#   Start Date    END DATE
# 0  2020-10-19 2020-12-11
# 1  2020-11-26 2020-12-05
# 2  2020-09-10 2021-02-02
# 3  2020-08-03 2021-01-06
# 4  2020-10-18 2021-01-05

# %%
df2.describe()
# Out:
# C:\Users\Legion\AppData\Local\Temp/ipykernel_20924/2610969840.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df2.describe()
# C:\Users\Legion\AppData\Local\Temp/ipykernel_20924/2610969840.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df2.describe()
#                       process         Process ID           Machine ID  \
# count                      36                 36                   36
# unique                      9                 36                   36
# top     Component Integration  SAWM3036_FA_WM128  MAII1017ECME3020079
# ...

# %%
df1
# Out:
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# 8                 pump    T110                                  plastics
# 9             spin tub    T111  steel (enameling iron) Porcelain coating
# 10            wash tub    T112        (enameling iron) Porcelain coating
# 11        balance ring    T113                           stainless steel
# ...

# %%
# Check for duplicate rows
duplicate_rows = df2.duplicated()
if duplicate_rows.any():
    print("There are duplicate rows in the dataframe")
else:
    print("There are no duplicate rows in the dataframe")
# Out:
# There are no duplicate rows in the dataframe

# %%
# Check for duplicate rows
duplicate_rows = df2.duplicated()
if duplicate_rows.any():
    print("There are duplicate rows in the dataframe")
else:
    print("There are no duplicate rows in the dataframe")
# Out:
# There are no duplicate rows in the dataframe

# %%
new_row = {'item': 'tub',
           'item id': 'T101', 
           'raw material': 'sheet steel', 
           'Quantity': '10 sqft', 
           'in date': '14/02/2020',
           'out date':'21/02/2020'}
new_row
# Out:
# {'item': 'tub',
#  'item id': 'T101',
#  'raw material': 'sheet steel',
#  'Quantity': '10 sqft',
#  'in date': '14/02/2020',
#  'out date': '21/02/2020'}

# %%
# # check if new_row is a duplicate row
# is_duplicate = df.duplicated(keep='last').any() and df1[df1.eq(new_row)].dropna(how='any').shape[0] == len(new_row)

# if is_duplicate:
#     print("The new row is a duplicate.")
# else:
#     print("The new row is not a duplicate.")

# df1

# append the new row to the DataFrame
df1 = df1.append(new_row, ignore_index=True)
df1
# Out:
# C:\Users\Legion\AppData\Local\Temp/ipykernel_20924/803977147.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(new_row, ignore_index=True)
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# ...

# %%
is_duplicate = df1.duplicated(subset=new_row)
is_duplicate
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29     True
# dtype: bool

# %%
if is_duplicate.any():
    print("New row is a duplicate row")
else:
    print("New row is not a duplicate row")
# Out:
# New row is a duplicate row

# %%
df1.drop_duplicates(inplace=True)

# %%
df1
# Out:
#                   item item id                              raw material  \
# 0                  tub    T101                               sheet steel
# 1                 pump    T102                                  plastics
# 2             spin tub    T103                           stainless steel
# 3             wash tub    T104        (enameling iron) Porcelain coating
# 4         balance ring    T105                                  plastics
# 5   transmission gears    T107                             cast aluminum
# 6     plastic brackets    T108                                  plastics
# 7                  tub    T109                               sheet steel
# 8                 pump    T110                                  plastics
# 9             spin tub    T111  steel (enameling iron) Porcelain coating
# 10            wash tub    T112        (enameling iron) Porcelain coating
# 11        balance ring    T113                           stainless steel
# ...
